# %%
from signalTeste import *
import numpy as np
import sounddevice as sd
import matplotlib.pyplot as plt
#import wave
import time as tp
import pickle
import peakutils
# %matplotlib inline

# %%
signal = signalMeu()

# %%
fs = 48000
time, sinal = signal.generateSin(500,1,2,fs)
time, sinal1 = signal.generateSin(520,1,2,fs)
time, sinal2 = signal.generateSin(100,2,2,fs)
sinalF = np.add(sinal, sinal1)
sinalF = np.add(sinalF, sinal2)/3
#myrecording = sd.playrec(sinalF, fs, channels=1)

# %%
plt.plot(time[:1000], sinalF[:1000])
plt.show()

# %%
frequencies, amplitude = signal.calcFFT(sinalF[:2000],fs)

plt.plot(frequencies,amplitude)
plt.show()

# %%
def geraNum(number = 1, amplitude=1, duration = 1, fs=48000):
    listaFreq = [[941,1336], [697,1209],
                 [697,1336], [697,1477],
                 [770,1209], [770,1336],
                 [770,1477], [852,1209],
                 [852,1336], [852,1477] ]
    print(listaFreq[number])
    time, sinal = signal.generateSin(listaFreq[number][0],amplitude,duration,fs)
    time, sinal1 = signal.generateSin(listaFreq[number][1],amplitude,duration,fs)
    sinalF = np.add(sinal, sinal1)/2
    
    return time,sinalF

# %%
tempo, sinalao = geraNum(number=9, duration=0.3)
myrecording = sd.playrec(sinalao, fs, channels=1)
sd.wait()
tempo, sinalao = geraNum(number=4, duration=0.3)
myrecording = sd.playrec(sinalao, fs, channels=1)
sd.wait()
tempo, sinalao = geraNum(number=6, duration=0.3)
myrecording = sd.playrec(sinalao, fs, channels=1)
sd.wait()
tempo, sinalao = geraNum(number=3, duration=0.3)
myrecording = sd.playrec(sinalao, fs, channels=1)
sd.wait()
tempo, sinalao = geraNum(number=3, duration=0.3)
myrecording = sd.playrec(sinalao, fs, channels=1)
sd.wait()
tempo, sinalao = geraNum(number=7, duration=0.3)
myrecording = sd.playrec(sinalao, fs, channels=1)
sd.wait()
tempo, sinalao = geraNum(number=8, duration=0.3)
myrecording = sd.playrec(sinalao, fs, channels=1)
sd.wait()
tempo, sinalao = geraNum(number=1, duration=0.3)
myrecording = sd.playrec(sinalao, fs, channels=1)
sd.wait()
tempo, sinalao = geraNum(number=4, duration=0.3)
myrecording = sd.playrec(sinalao, fs, channels=1)
sd.wait()
plt.plot(tempo[:500], sinalao[:500])
plt.show()
# Out:
# [852, 1477]
# [770, 1209]
# [770, 1477]
# [697, 1477]
# [697, 1477]
# [852, 1209]
# [852, 1336]
# [697, 1209]
# [770, 1209]

# %%
sd.wait()
tempo, sinalao = geraNum(number=1, duration=0.5)
myrecording = sd.playrec(sinalao, fs, channels=1)
# Out:
# [697, 1209]

# %%
time, sinal = signal.generateSin(700,1,4,fs)
myrecording = sd.playrec(sinal, fs, channels=1)

# %%
len(sinal)
# Out:
# 192000
